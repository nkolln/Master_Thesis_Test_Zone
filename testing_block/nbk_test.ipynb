# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('df_out.csv')

# %%
df.iloc[0]#['observations']
# Out:
# Unnamed: 0                                                           0
# observations         [[ 8.9656770e-02 -3.6221828e-02 -7.8041069e-02...
# next_observations    [[ 6.8606213e-02 -6.3024499e-02  1.2627374e-01...
# actions              [[ 0.78721416  0.8764658  -0.40471458 -0.82123...
# rewards              [-0.08235575 -0.42559636 -0.6561693  -0.035459...
# terminals            [False False False False False False False Fal...
# Name: 0, dtype: object

# %%
df['rewards'].shape[0]
# Out:
# 1000

# %%
with open('test.npy', 'rb') as f:

    a = np.load(f,allow_pickle=True)
print(a.shape)
print(a[0].shape)
# Out:
# (1000,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 5
#       3     a = np.load(f,allow_pickle=True)
#       4 print(a.shape)
# ----> 5 print(a[0].shape)
#
# AttributeError: 'dict' object has no attribute 'shape'

# %%
df = pd.read_pickle('halfcheetah-expert-v2.pkl', compression='infer')

# %%
df[0]
# Out:
# {'observations': array([[ 8.9656770e-02, -3.6221828e-02, -7.8041069e-02, ...,
#          -1.7055729e-01,  2.4560320e-01, -1.1097556e-01],
#         [ 6.8606213e-02, -6.3024499e-02,  1.2627374e-01, ...,
#          -5.8347492e+00,  2.9682204e-01, -6.3176913e+00],
#         [ 4.3157995e-02, -3.0180864e-02,  7.2917409e-02, ...,
#          -4.4513804e-01,  4.5849690e+00,  2.0110707e+00],
#         ...,
#         [-4.1689873e-02,  8.9871539e-03,  2.9549471e-01, ...,
#           2.0154961e+01,  1.1117487e+00,  5.6424284e+00],
#         [-2.2097768e-02,  8.8754773e-02, -5.4139125e-01, ...,
#           5.6769867e+00,  1.0659179e+01,  7.5137334e+00],
#         [-4.1285481e-02,  1.0447114e-02, -5.4612273e-01, ...,
#           9.1648026e+00, -4.9345508e+00, -1.8736249e+00]], dtype=float32),
#  'next_observations': array([[ 6.8606213e-02, -6.3024499e-02,  1.2627374e-01, ...,
#          -5.8347492e+00,  2.9682204e-01, -6.3176913e+00],
# ...

# %%
len(df[0]['observations'])
# Out:
# 1000

# %%
len(df[0])
# Out:
# 5

# %%
len(df)
# Out:
# 1000

# %%
pd.DataFrame.from_dict(a)
# Out:
#                                                      0
# 0    {'observations': [[0.08965677, -0.03622183, -0...
# 1    {'observations': [[-0.04450601, 0.028030245, -...
# 2    {'observations': [[-0.009840652, 0.017156245, ...
# 3    {'observations': [[0.06476112, -0.009150443, -...
# 4    {'observations': [[0.05451903, -0.015239877, -...
# ..                                                 ...
# 995  {'observations': [[-0.08598525, 0.0696964, -0....
# 996  {'observations': [[-0.031784464, -0.04686167, ...
# 997  {'observations': [[-0.048090488, -0.07412809, ...
# 998  {'observations': [[-0.013136743, 0.047820985, ...
# 999  {'observations': [[-0.06337035, -0.08084216, 0...
#
# [1000 rows x 1 columns]
